# %%
import json
import random
import numpy as np
import pandas as pd
from csv import DictWriter
from deap import base, creator, tools

# %%
json_handle = open(r'../results/Customized_Data_2', 'r', encoding = 'utf-8')
json_string = json_handle.read()
instance = json.loads(json_string)
demand_ls = []
pop_ls = []
start_index = 1

for i in range(1, 101):
    demand = instance[f'customer_{i}']['demand']
    demand_ls.append(demand)

for demand in demand_ls:
    pop_ls.extend([start_index] * int(demand))
    start_index += 1

print(len(pop_ls))
# Out:
# 1810

# %%
int_pop_ls = []
every_demand = []
int_start_index = 1
max_vehicle_number = instance['max_vehicle_number']

for demand in demand_ls:
    integer = demand // max_vehicle_number
    remainder = demand % max_vehicle_number
    
    if remainder == 0:
        int_pop_ls.extend([int_start_index] * int(integer))
        every_demand.extend([max_vehicle_number] * int(integer))
    else:
        int_pop_ls.extend([int_start_index] * (int(integer)+1))
        every_demand.extend([max_vehicle_number] * int(integer) + [int(remainder)])
    int_start_index += 1
    
integrate_customer_demand = list(zip(int_pop_ls, every_demand))   

#print(int_pop_ls)
print(integrate_customer_demand[:10])
# Out:
# [(1, 3), (1, 3), (1, 3), (1, 1), (2, 3), (2, 3), (2, 3), (2, 3), (2, 3), (2, 3)]

# %%
def ind2route(individual, instance): 
    '''decoding'''
    route = []
    depart_due_time = instance['depart']['due_time']
    max_vehicle_number = instance['max_vehicle_number']
    elapsed_time = 0
    initial_demand_ls = list(map(list, individual))

    for customer_demand in initial_demand_ls:
        
        customer_index = customer_demand[0]
        each_demand = customer_demand[1]
        
        due_time = instance[f'customer_{customer_index}']['due_time']
        service_time = instance[f'customer_{customer_index}']['service_time']
        travel_time = instance['distance_matrix'][0][customer_index]
            
        # Update elapsed time
        updated_elapsed_time = elapsed_time + each_demand*service_time + 2*travel_time

        # Validate vehicle load and elapsed time
        if each_demand !=0 and (updated_elapsed_time <= depart_due_time) and \
            (updated_elapsed_time - travel_time < due_time):   
            # Add to current sub-route
            route.append((customer_index, each_demand))
            elapsed_time = updated_elapsed_time
            each_demand = 0

    return route

# %%
def print_route(route): 
    '''print route'''
    route_str = '0'
    for customer_demand in route:
        customer_index = customer_demand[0]
        route_str = f'{route_str} - {customer_index} - 0'
    print(f"integrated_route: {route_str}")

# %%
def eval_vrptw(individual, instance, unit_cost=1.0, init_cost=0, wait_cost=0): 
    '''fitness function'''
    route = ind2route(individual, instance)
    total_unsaving_demand = len(pop_ls)
    max_vehicle_number = instance['max_vehicle_number']
    elapsed_time = 0
    total_cost = 0
    time_cost = 0
    unsaving_cost = 0
    
    for customer_demand in route:
        customer_index = customer_demand[0]
        each_demand = customer_demand[1]
        
        ready_time = instance[f'customer_{customer_index}']['ready_time']
        service_time = instance[f'customer_{customer_index}']['service_time']
        distance = instance['distance_matrix'][0][customer_index]
        
        # Calculate time cost
        arrival_time = elapsed_time + distance
        time_cost += max_vehicle_number * wait_cost * max(ready_time - arrival_time, 0)
        # Update elapsed time
        elapsed_time = arrival_time + each_demand*service_time + distance
        
        # Calculate unsaving demand
        total_unsaving_demand += - each_demand
        
    # Calculate unsaving cost
    unsaving_cost = init_cost + unit_cost * total_unsaving_demand
    
    # Obtain total cost
    total_cost = time_cost + unsaving_cost
    
    fitness = 1.0 / total_cost * 10**6
    return (fitness, )

# %%
def mut_inverse_indexes(individual): 
    '''mutation rules'''
    start, stop = sorted(random.sample(range(len(individual)), 2))
    temp = individual[start:stop+1]
    temp.reverse()
    individual[start:stop+1] = temp
    return (individual, )

# %%
def run_gavrptw(instance, unit_cost, init_cost, wait_cost, ind_size, pop_size, \
    cx_pb, mut_pb, n_gen, export_csv=False):
    
    
    #define types
    creator.create('FitnessMax', base.Fitness, weights=(1.0, ))
    creator.create('Individual', list, fitness=creator.FitnessMax)

    #initialization
    toolbox = base.Toolbox()
    toolbox.register('indexes', random.sample, integrate_customer_demand, ind_size)
    toolbox.register('individual', tools.initIterate, creator.Individual, toolbox.indexes)
    toolbox.register('population', tools.initRepeat, list, toolbox.individual)

    #operatiors
    toolbox.register('evaluate', eval_vrptw, instance=instance, unit_cost=unit_cost, \
                      init_cost=init_cost, wait_cost=wait_cost)
    toolbox.register('select', tools.selRoulette)
    toolbox.register('mate', tools.cxTwoPoint)
    toolbox.register('mutate', mut_inverse_indexes)
    
    pop = toolbox.population(n=pop_size)

    # Evaluate the entire population
    fitnesses = list(map(toolbox.evaluate, pop))
    for ind, fit in zip(pop, fitnesses):
        ind.fitness.values = fit

    for g in range(n_gen):
        # Select the next generation individuals
        offspring = toolbox.select(pop, len(pop))
        # Clone the selected individuals
        offspring = list(map(toolbox.clone, offspring))

        # Apply crossover and mutation on the offspring
        for child1, child2 in zip(offspring[::2], offspring[1::2]):
            if random.random() < cx_pb:
                toolbox.mate(child1, child2)
                del child1.fitness.values
                del child2.fitness.values

        for mutant in offspring:
            if random.random() < mut_pb:
                toolbox.mutate(mutant)
                del mutant.fitness.values

        # Evaluate the individuals with an invalid fitness
        invalid_ind = [ind for ind in offspring if not ind.fitness.valid]
        fitnesses = list(map(toolbox.evaluate, invalid_ind))
        for ind, fit in zip(invalid_ind, fitnesses):
            ind.fitness.values = fit
            
        print(f' Evaluated {len(invalid_ind)} individuals')
        
        # The population is entirely replaced by the offspring
        pop[:] = offspring

        # Gather all the fitnesses in one list and print the stats
        fits = [ind.fitness.values[0] for ind in pop]
        length = len(pop)
        mean = sum(fits) / length
        sum2 = sum([x**2 for x in fits])
        std = abs(sum2 / length - mean**2)**0.5
        print(f'  Min {round(min(fits), 6)}')
        print(f'  Max {round(max(fits), 6)}')
        print(f'  Avg {round(mean, 6)}')
        print(f'  Std {round(std, 6)}')
        
    print('-- End of (successful) evolution --')
    
    best_ind = tools.selBest(pop, 1)[0]
    print(f'the best individual: {best_ind}')
    print(f'Fitness: {round(best_ind.fitness.values[0], 6)}')
    print_route(ind2route(best_ind, instance))
    print(f'Total cost: {1 / best_ind.fitness.values[0] * 10**6}')
   
        
    return pop

# %%
def main():
    '''main()'''
    random.seed(2022)

    instance = json.loads(json_string)

    unit_cost = 500.0
    init_cost = 0.0
    wait_cost = 10

    ind_size = 300
    pop_size = 100
    cx_pb = 0.9
    mut_pb = 0.1
    n_gen = 100

    export_csv = True

    run_gavrptw(instance=instance, unit_cost=unit_cost, init_cost=init_cost, \
        wait_cost=wait_cost, ind_size=ind_size, pop_size=pop_size, \
        cx_pb=cx_pb, mut_pb=mut_pb, n_gen=n_gen, export_csv=export_csv)


if __name__ == '__main__':
    main()
# Out:
#  Evaluated 83 individuals
#   Min 1.02182
#   Max 1.082929
#   Avg 1.064009
#   Std 0.011894
#  Evaluated 90 individuals
#   Min 1.040161
#   Max 1.084186
#   Avg 1.065282
#   Std 0.009698
#  Evaluated 81 individuals
#   Min 1.040161
#   Max 1.082536
#   Avg 1.065791
#   Std 0.009301
#  Evaluated 88 individuals
#   Min 1.042917
#   Max 1.082536
#   Avg 1.067346
#   Std 0.009242
#  Evaluated 95 individuals
#   Min 1.047461
#   Max 1.085808
#   Avg 1.068835
#   Std 0.00934
#  Evaluated 89 individuals
#   Min 1.049509
#   Max 1.085808
#   Avg 1.069739
#   Std 0.009003
#  Evaluated 94 individuals
#   Min 1.052006
#   Max 1.088607
#   Avg 1.069837
#   Std 0.008401
#  Evaluated 89 individuals
#   Min 1.035478
#   Max 1.082929
#   Avg 1.068087
#   Std 0.009018
#  Evaluated 96 individuals
#   Min 1.052115
#   Max 1.0813
#   Avg 1.066626
#   Std 0.009032
#  Evaluated 89 individuals
#   Min 1.052115
#   Max 1.0813
#   Avg 1.066141
#   Std 0.008975
#  Evaluated 93 individuals
#   Min 1.046355
#   Max 1.0839
#   Avg 1.067972
#   Std 0.008768
#  Evaluated 85 individuals
#   Min 1.052115
#   Max 1.080424
#   Avg 1.067886
#   Std 0.008616
#  Evaluated 92 individuals
#   Min 1.052115
#   Max 1.0806
#   Avg 1.068336
#   Std 0.008279
#  Evaluated 89 individuals
#   Min 1.051358
#   Max 1.080978
#   Avg 1.06904
#   Std 0.007695
#  Evaluated 89 individuals
#   Min 1.047047
#   Max 1.079047
#   Avg 1.068759
#   Std 0.00796
#  Evaluated 95 individuals
#   Min 1.051358
#   Max 1.082849
#   Avg 1.069603
#   Std 0.007918
#  Evaluated 87 individuals
#   Min 1.051358
#   Max 1.079047
#   Avg 1.070364
#   Std 0.007518
#  Evaluated 90 individuals
#   Min 1.051358
#   Max 1.082545
#   Avg 1.07097
#   Std 0.006901
#  Evaluated 91 individuals
#   Min 1.051358
#   Max 1.082545
#   Avg 1.071672
#   Std 0.006743
#  Evaluated 89 individuals
#   Min 1.053586
#   Max 1.082545
#   Avg 1.073287
#   Std 0.005936
#  Evaluated 94 individuals
#   Min 1.055546
#   Max 1.082545
#   Avg 1.073768
#   Std 0.005446
#  Evaluated 91 individuals
#   Min 1.055444
#   Max 1.082545
#   Avg 1.074017
#   Std 0.004471
#  Evaluated 94 individuals
#   Min 1.056103
#   Max 1.080688
#   Avg 1.07422
#   Std 0.004362
#  Evaluated 97 individuals
#   Min 1.056103
#   Max 1.080688
#   Avg 1.074244
#   Std 0.004187
#  Evaluated 89 individuals
#   Min 1.056103
#   Max 1.079649
#   Avg 1.07369
#   Std 0.004907
#  Evaluated 95 individuals
#   Min 1.056103
#   Max 1.079649
#   Avg 1.074221
#   Std 0.004002
#  Evaluated 90 individuals
#   Min 1.056103
#   Max 1.079649
#   Avg 1.073896
#   Std 0.003965
#  Evaluated 93 individuals
#   Min 1.056103
#   Max 1.078952
#   Avg 1.073369
#   Std 0.004664
#  Evaluated 88 individuals
#   Min 1.056103
#   Max 1.078952
#   Avg 1.073386
#   Std 0.004486
#  Evaluated 90 individuals
#   Min 1.053606
#   Max 1.078952
#   Avg 1.072796
#   Std 0.005237
#  Evaluated 91 individuals
#   Min 1.053606
#   Max 1.078952
#   Avg 1.072782
#   Std 0.005016
#  Evaluated 89 individuals
#   Min 1.053606
#   Max 1.078952
#   Avg 1.071683
#   Std 0.006777
#  Evaluated 96 individuals
#   Min 1.053606
#   Max 1.080011
#   Avg 1.071833
#   Std 0.006823
#  Evaluated 92 individuals
#   Min 1.053586
#   Max 1.079649
#   Avg 1.071457
#   Std 0.007187
#  Evaluated 92 individuals
#   Min 1.053606
#   Max 1.079649
#   Avg 1.071522
#   Std 0.00689
#  Evaluated 85 individuals
#   Min 1.053606
#   Max 1.078952
#   Avg 1.072164
#   Std 0.006337
#  Evaluated 86 individuals
#   Min 1.053606
#   Max 1.078952
#   Avg 1.072245
#   Std 0.005756
#  Evaluated 98 individuals
#   Min 1.053176
#   Max 1.078952
#   Avg 1.073067
#   Std 0.005589
#  Evaluated 93 individuals
#   Min 1.053176
#   Max 1.078952
#   Avg 1.073173
#   Std 0.005481
#  Evaluated 88 individuals
#   Min 1.051377
#   Max 1.079649
#   Avg 1.072395
#   Std 0.00628
#  Evaluated 93 individuals
#   Min 1.055426
#   Max 1.078952
#   Avg 1.072451
#   Std 0.005034
#  Evaluated 88 individuals
#   Min 1.055426
#   Max 1.078952
#   Avg 1.072082
#   Std 0.005511
#  Evaluated 93 individuals
#   Min 1.053176
#   Max 1.080424
#   Avg 1.071785
#   Std 0.00564
#  Evaluated 90 individuals
#   Min 1.055426
#   Max 1.079649
#   Avg 1.071918
#   Std 0.005288
#  Evaluated 94 individuals
#   Min 1.055426
#   Max 1.079649
#   Avg 1.072976
#   Std 0.004221
#  Evaluated 86 individuals
#   Min 1.055426
#   Max 1.078952
#   Avg 1.072875
#   Std 0.004189
#  Evaluated 85 individuals
#   Min 1.055426
#   Max 1.078952
#   Avg 1.073414
#   Std 0.003479
#  Evaluated 94 individuals
#   Min 1.055426
#   Max 1.078952
#   Avg 1.073392
#   Std 0.003335
#  Evaluated 90 individuals
#   Min 1.051377
#   Max 1.078952
#   Avg 1.073114
#   Std 0.004043
#  Evaluated 96 individuals
#   Min 1.051377
#   Max 1.079649
#   Avg 1.073141
#   Std 0.00429
#  Evaluated 89 individuals
#   Min 1.051377
#   Max 1.079649
#   Avg 1.072988
#   Std 0.005186
#  Evaluated 90 individuals
#   Min 1.055426
#   Max 1.079649
#   Avg 1.073876
#   Std 0.003376
#  Evaluated 99 individuals
#   Min 1.055426
#   Max 1.079649
#   Avg 1.073899
#   Std 0.003354
#  Evaluated 92 individuals
#   Min 1.055426
#   Max 1.079649
#   Avg 1.073686
#   Std 0.003249
#  Evaluated 94 individuals
#   Min 1.068317
#   Max 1.078952
#   Avg 1.073496
#   Std 0.002541
#  Evaluated 94 individuals
#   Min 1.068317
#   Max 1.082752
#   Avg 1.073872
#   Std 0.002618
#  Evaluated 95 individuals
#   Min 1.068941
#   Max 1.078952
#   Avg 1.073601
#   Std 0.002216
#  Evaluated 94 individuals
#   Min 1.069253
#   Max 1.080011
#   Avg 1.073605
#   Std 0.002485
#  Evaluated 94 individuals
#   Min 1.069253
#   Max 1.080011
#   Avg 1.073591
#   Std 0.002409
#  Evaluated 86 individuals
#   Min 1.067603
#   Max 1.08069
#   Avg 1.073706
#   Std 0.002599
#  Evaluated 92 individuals
#   Min 1.065516
#   Max 1.082589
#   Avg 1.073715
#   Std 0.002784
#  Evaluated 90 individuals
#   Min 1.065516
#   Max 1.082589
#   Avg 1.073568
#   Std 0.003018
#  Evaluated 89 individuals
#   Min 1.065516
#   Max 1.082589
#   Avg 1.073757
#   Std 0.003091
#  Evaluated 90 individuals
#   Min 1.065516
#   Max 1.082589
#   Avg 1.07366
#   Std 0.003576
#  Evaluated 92 individuals
#   Min 1.065516
#   Max 1.082589
#   Avg 1.074104
#   Std 0.003932
#  Evaluated 91 individuals
#   Min 1.065516
#   Max 1.082589
#   Avg 1.074126
#   Std 0.003803
#  Evaluated 97 individuals
#   Min 1.065516
#   Max 1.082589
#   Avg 1.073503
#   Std 0.003874
#  Evaluated 97 individuals
#   Min 1.065516
#   Max 1.082589
#   Avg 1.072655
#   Std 0.003975
#  Evaluated 84 individuals
#   Min 1.065516
#   Max 1.082589
#   Avg 1.072299
#   Std 0.004239
#  Evaluated 90 individuals
#   Min 1.065516
#   Max 1.082589
#   Avg 1.071197
#   Std 0.004322
#  Evaluated 86 individuals
#   Min 1.065516
#   Max 1.08069
#   Avg 1.071273
#   Std 0.004515
#  Evaluated 93 individuals
#   Min 1.065516
#   Max 1.08069
#   Avg 1.071296
#   Std 0.004473
#  Evaluated 89 individuals
#   Min 1.065516
#   Max 1.080011
#   Avg 1.071263
#   Std 0.004622
#  Evaluated 94 individuals
#   Min 1.065516
#   Max 1.08069
#   Avg 1.071392
#   Std 0.004979
#  Evaluated 80 individuals
#   Min 1.065516
#   Max 1.080011
#   Avg 1.071612
#   Std 0.004663
#  Evaluated 96 individuals
#   Min 1.065516
#   Max 1.080011
#   Avg 1.071545
#   Std 0.004813
#  Evaluated 91 individuals
#   Min 1.065516
#   Max 1.080011
#   Avg 1.071289
#   Std 0.004934
#  Evaluated 85 individuals
#   Min 1.065516
#   Max 1.080011
#   Avg 1.071487
#   Std 0.005074
#  Evaluated 89 individuals
#   Min 1.065516
#   Max 1.081437
#   Avg 1.072133
#   Std 0.004889
#  Evaluated 89 individuals
#   Min 1.065516
#   Max 1.082278
#   Avg 1.07176
#   Std 0.004605
#  Evaluated 91 individuals
#   Min 1.065516
#   Max 1.080601
#   Avg 1.071994
#   Std 0.004542
#  Evaluated 96 individuals
#   Min 1.065516
#   Max 1.080601
#   Avg 1.071704
#   Std 0.004001
#  Evaluated 97 individuals
#   Min 1.065516
#   Max 1.080601
#   Avg 1.071774
#   Std 0.004154
#  Evaluated 96 individuals
#   Min 1.065516
#   Max 1.081672
#   Avg 1.0717
#   Std 0.004115
#  Evaluated 94 individuals
#   Min 1.065516
#   Max 1.081672
#   Avg 1.071841
#   Std 0.004151
#  Evaluated 93 individuals
#   Min 1.065516
#   Max 1.079649
#   Avg 1.070804
#   Std 0.00378
#  Evaluated 91 individuals
#   Min 1.065516
#   Max 1.07956
#   Avg 1.072263
#   Std 0.003472
#  Evaluated 87 individuals
#   Min 1.065516
#   Max 1.079078
#   Avg 1.072348
#   Std 0.003367
#  Evaluated 93 individuals
#   Min 1.065516
#   Max 1.079649
#   Avg 1.072272
#   Std 0.003606
#  Evaluated 92 individuals
#   Min 1.064406
#   Max 1.078807
#   Avg 1.072125
#   Std 0.003502
#  Evaluated 91 individuals
#   Min 1.065516
#   Max 1.082491
#   Avg 1.072751
#   Std 0.00333
#  Evaluated 87 individuals
#   Min 1.062276
#   Max 1.082491
#   Avg 1.073298
#   Std 0.00358
#  Evaluated 87 individuals
#   Min 1.056305
#   Max 1.079587
#   Avg 1.073406
#   Std 0.003699
#  Evaluated 92 individuals
#   Min 1.062276
#   Max 1.08074
#   Avg 1.073676
#   Std 0.003111
#  Evaluated 95 individuals
#   Min 1.062276
#   Max 1.079649
#   Avg 1.073631
#   Std 0.003389
#  Evaluated 90 individuals
#   Min 1.064934
#   Max 1.079649
#   Avg 1.073979
#   Std 0.003365
#  Evaluated 92 individuals
#   Min 1.064934
#   Max 1.079908
#   Avg 1.074022
#   Std 0.003708
#  Evaluated 93 individuals
#   Min 1.064643
#   Max 1.079587
#   Avg 1.073125
#   Std 0.003733
#  Evaluated 96 individuals
#   Min 1.065516
#   Max 1.079649
#   Avg 1.072959
#   Std 0.003827
#  Evaluated 87 individuals
#   Min 1.064934
#   Max 1.080471
#   Avg 1.072537
#   Std 0.004177
# -- End of (successful) evolution --
# the best individual: [(37, 3), (88, 3), (37, 3), (42, 3), (36, 3), (65, 3), (7, 3), (56, 3), (35, 3), (39, 3), (95, 3), (5, 1), (94, 3), (28, 3), (16, 3), (60, 3), (57, 3), (50, 3), (93, 3), (61, 3), (87, 3), (93, 3), (24, 3), (18, 3), (20, 3), (7, 3), (46, 3), (61, 3), (15, 3), (96, 3), (2, 3), (42, 3), (87, 3), (68, 1), (61, 3), (78, 2), (1, 3), (50, 3), (16, 3), (12, 2), (74, 3), (6, 3), (81, 3), (63, 3), (71, 3), (8, 3), (95, 3), (63, 3), (85, 3), (71, 3), (62, 3), (49, 3), (54, 3), (90, 3), (56, 3), (79, 1), (95, 3), (81, 3), (85, 3), (48, 3), (20, 3), (2, 3), (22, 3), (21, 2), (12, 3), (56, 3), (59, 3), (89, 3), (47, 3), (82, 3), (61, 3), (8, 3), (34, 2), (59, 3), (92, 3), (58, 3), (84, 2), (85, 3), (88, 3), (1, 1), (33, 1), (49, 1), (66, 3), (51, 3), (95, 3), (23, 3), (6, 3), (81, 3), (63, 3), (15, 3), (99, 3), (4, 3), (63, 3), (74, 3), (38, 3), (59, 3), (29, 3), (35, 3), (8, 3), (32, 3), (30, 3), (62, 3), (17, 3), (8, 3), (91, 3), (16, 3), (53, 3), (38, 3), (2, 3), (61, 3), (68, 1), (87, 3), (29, 3), (92, 3), (43, 1), (97, 3), (87, 3), (40, 1), (2, 3), (50, 1), (37, 3), (47, 3), (5, 3), (84, 3), (39, 3), (69, 3), (24, 3), (10, 1), (39, 3), (81, 3), (29, 3), (58, 3), (60, 3), (94, 3), (25, 3), (17, 3), (35, 3), (86, 1), (37, 3), (74, 3), (93, 3), (30, 1), (87, 3), (2, 3), (46, 3), (75, 3), (88, 3), (40, 3), (54, 3), (20, 3), (65, 1), (15, 3), (33, 3), (57, 3), (21, 3), (74, 3), (37, 3), (6, 3), (17, 3), (8, 3), (95, 3), (2, 3), (25, 3), (8, 3), (5, 3), (35, 3), (58, 3), (20, 3), (48, 1), (61, 3), (82, 3), (56, 3), (85, 3), (88, 3), (74, 3), (42, 3), (46, 3), (7, 3), (48, 1), (93, 3), (24, 3), (18, 3), (71, 3), (56, 3), (30, 1), (93, 3), (63, 3), (16, 3), (97, 3), (85, 3), (88, 3), (77, 3), (82, 3), (79, 3), (53, 2), (81, 3), (59, 3), (70, 3), (34, 3), (97, 3), (95, 3), (39, 3), (81, 3), (70, 3), (57, 3), (71, 3), (7, 3), (56, 3), (35, 3), (39, 3), (95, 3), (4, 3), (15, 3), (92, 2), (57, 3), (35, 3), (86, 1), (63, 3), (61, 1), (25, 3), (89, 3), (33, 3), (71, 3), (56, 3), (78, 3), (66, 1), (84, 2), (85, 3), (88, 3), (38, 3), (97, 3), (93, 3), (22, 3), (15, 3), (7, 3), (56, 3), (35, 3), (39, 3), (28, 3), (1, 1), (99, 3), (43, 1), (92, 3), (80, 3), (27, 3), (68, 1), (61, 3), (2, 3), (38, 3), (53, 3), (16, 3), (91, 3), (8, 3), (17, 3), (62, 3), (30, 3), (32, 3), (8, 3), (35, 3), (30, 3), (31, 3), (99, 3), (17, 3), (34, 3), (1, 3), (25, 3), (79, 1), (50, 3), (21, 3), (17, 3), (62, 3), (30, 3), (32, 3), (25, 3), (13, 3), (74, 3), (100, 3), (93, 3), (18, 3), (24, 3), (93, 3), (25, 3), (16, 3), (25, 1), (46, 3), (39, 3), (82, 3), (48, 3), (88, 3), (95, 3), (38, 3), (95, 3), (57, 3), (92, 3), (59, 3), (88, 3), (59, 3), (79, 3), (69, 3), (57, 3)]
# Fitness: 1.080471
# integrated_route: 0 - 37 - 0 - 88 - 0 - 1 - 0
# Total cost: 925522.1647747048
